# %% [markdown]
# <a href="https://colab.research.google.com/github/Sidy3143/TinyGPT/blob/main/TinyGPT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Generative Model trained on TinyStories dataset

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import math
import inspect

# %% [markdown]
# Model architecture

# %%
class CausalAttention(nn.Module):
  def __init__(self, n_head, n_embed, seq_len, dropout, bias=False, trainning=True):
    super().__init__()

    assert n_embed % n_head == 0, "n_embed must be divisible by n_head"
    self.n_embed = n_embed
    self.n_head = n_head
    self.h_dim = self.n_embed // self.n_head

    self.QKV = nn.Linear(n_embed, 3 * n_embed, bias=bias)
    self.out = nn.Linear(n_embed, n_embed, bias=bias)

    self.att_dropout = nn.Dropout(dropout)
    self.out_dropout = nn.Dropout(dropout)
    self.dropout = dropout
    self.training = trainning

    self.flash = hasattr(torch.nn.functional ,'scaled_dot_product_attention')
    if not self.flash:
      print("No flashattention, GPUs will not be going brrr")
      self.register_buffer("mask", torch.tril(torch.ones(seq_len, seq_len)).view(1, 1, seq_len, seq_len))

  def forward(self, input): # b, T, n_embed
    B, T, _ = input.size()

    query, key, value = self.QKV(input).split(self.n_embed, 2)

    query = query.view(B, T, self.n_head, self.h_dim).transpose(1, 2) # B, n_head, T, h_dim
    key = key.view(B, T, self.n_head, self.h_dim).transpose(1, 2)
    value = value.view(B, T, self.n_head, self.h_dim).transpose(1, 2)

    if self.flash:
        attention_output = F.scaled_dot_product_attention(query, key, value, attn_mask=None, dropout_p=self.dropout if self.training else 0, is_causal=True)

    else:
        att = (query @ key.transpose(-1, -2)) * (1 / math.sqrt(self.h_dim)) # B, n_head, T, T
        att = att.masked_fill_(self.mask[:, :, :T, :T] ==0, float('-inf'))
        if self.dropout:
          att = self.att_dropout(att)
        attention_scores = torch.softmax(att, dim=-1)
        attention_output = attention_scores @ value # B, n_head, T, h_dim

        #attention_scores = attention_scores.transpose(1, 2).contiguous().view(B, T, -1)

    attention_output = attention_output.transpose(1, 2).contiguous().view(B, T, -1) # B, T, n_embed

    out = self.out_dropout(self.out(attention_output))

    return out #B, T, n_embed

# %%
class SWIGLUFFN(nn.Module):
 def __init__(self, n_embed, dropout, bias):
  super().__init__()

  hidden_dim = 4 * n_embed
  hidden_dim = int(2 * hidden_dim/3)
  self.layer1 = nn.Linear(n_embed, hidden_dim, bias=bias)
  self.silu = nn.SiLU()
  self.layer2 = nn.Linear(n_embed, hidden_dim, bias=bias)
  self.layer3 = nn.Linear(hidden_dim, n_embed, bias=bias)

  self.dropout = nn.Dropout(dropout)

 def forward(self, x):
    x = self.silu(self.layer1(x)) * self.layer2(x)
    x = self.dropout(self.layer3(x))

    return x

# %%
class Block(nn.Module):
  def __init__(self, config):
    super().__init__()

    self.norm1 = nn.RMSNorm(config.n_embed)
    self.Causal_attention = CausalAttention(config.n_head, config.n_embed, config.seq_len, config.dropout, config.bias)
    self.norm2 = nn.RMSNorm(config.n_embed)
    self.Feed_forward = SWIGLUFFN(config.n_embed, config.dropout, config.bias)

  def forward(self, x): # B, T, n_embed
    x = x + self.Causal_attention(self.norm1(x))
    x = x + self.Feed_forward(self.norm2(x))

    return x

# %%
class GPT(nn.Module):
  def __init__(self, GPTConfig):
    super().__init__()

    self.vocab_size = GPTConfig.vocab_size
    self.n_embed = GPTConfig.n_embed
    self.n_head = GPTConfig.n_head

    self.seq_len = GPTConfig.seq_len
    self.n_layers = GPTConfig.n_layers
    self.dropout = GPTConfig.dropout

    self.transformer = nn.ModuleDict(dict(
        token_embed = nn.Embedding(self.vocab_size, self.n_embed),
        pos_embed = nn.Embedding(self.seq_len, self.n_embed),
        drop = nn.Dropout(self.dropout),
        blocks = nn.ModuleList([Block(GPTConfig) for _ in range(self.n_layers)]),
        norm = nn.RMSNorm(self.n_embed),
    ))

    self.projection = nn.Linear(self.n_embed, self.vocab_size, bias=False)

    #weight tying
    self.transformer.token_embed.weight = self.projection.weight

    self.apply(self._init_weights)

  def _init_weights(self, module):
    if isinstance(module, nn.Linear):
      nn.init.normal_(module.weight, mean=0.0, std=0.02)
      if module.bias is not None:
        nn.init.zeros_(module.bias)

    elif isinstance(module, nn.Embedding):
      nn.init.normal_(module.weight, mean=0.0, std=0.02)


  def get_num_params(self, non_embedding=True):
    num_params = sum(p.numel() for p in self.parameters())
    if non_embedding:
      num_params -= self.transformer.pos_embed.weight.numel()
    return num_params

  def forward(self, ids, targets=None): #B, T
    B, T = ids.size()
    device = ids.device

    assert T <= self.seq_len, f"cannot process setences with more than {self.seq_len}"
    positions = torch.arange(0, T, dtype=torch.long, device=device)  # T, n_embed

    token_embeddings = self.transformer.token_embed(ids)  # B, T, n_embed
    pos_embeddings = self.transformer.pos_embed(positions)
    x = self.transformer.drop(token_embeddings + pos_embeddings)

    for block in self.transformer.blocks:
      x = block(x)
    out = self.transformer.norm(x) # B, T, n_embed

    if targets is not None:
      logits = self.projection(out) # B, T, vocab_size
      loss = F.cross_entropy(logits.view(-1, self.vocab_size), targets.view(-1), ignore_index=-100)

    else: # inference
      logits = self.projection(out[:, [-1], :]) # small optimization for inference
      loss = None

    return logits, loss


  def configure_optimizers(self, weight_decay, learning_rate, betas):
    params = {n:p for n,p in self.named_parameters()}
    params = {n:p for n,p in params.items() if p.requires_grad}

    decay_params = [p for n,p in params.items() if p.dim() >= 2]
    non_decay_params = [p for n,p in params.items() if p.dim() < 2]
    optim_params = [
        {'params': decay_params, 'weight_decay': weight_decay},
        {'params': non_decay_params, 'weight_decay': 0.0}
      ]
    num_decay_params = sum(p.numel() for p in decay_params)
    num_non_decay_params = sum(p.numel() for p in non_decay_params)
    print(f"number of non decay params: {num_decay_params}")
    print(f"number of non decay params: {num_non_decay_params}")

    fused_available = 'fused' in inspect.signature(torch.optim.AdamW).parameters
    fuse_dict = dict(fused=True) if fused_available else dict()
    optimizer = torch.optim.AdamW(optim_params, lr=learning_rate, betas=betas, **fuse_dict)

    return optimizer


  def estimate_mfu(self, fwd_per_iter, dt): # according to Palm paper
    N = self.get_num_params()

    L, H, Q, T = self.n_layers, self.n_head, self.n_embed//self.n_head, self.seq_len
    flops_per_token = 6*N + 12*L*H*Q*T
    flops_fwd_bwd = flops_per_token * T
    flops_per_iter = flops_fwd_bwd * fwd_per_iter

    flops_achieved = flops_per_iter * (1.0/dt)
    flops_promised = 120e12 # A100 GPU bfloat16 peak flops is 312 TFLOPS, T4 is 65 Tflops, 120 for L4GPU

    mfu = flops_achieved / flops_promised
    return mfu


  @torch.no_grad()
  def generate(self, text_ids, eos_id, max_samples, temperature=1.0, top_k=None, top_p=None, min_p=None, greedy=False):
    #prompt : B, T
    self.eval() # put in eval mode
    response = torch.empty(1, 0, dtype=torch.int64, device=text_ids.device)
    for _ in range(max_samples):
        text_wdw = text_ids if text_ids.size(1)<=self.seq_len else text_ids[:, -self.seq_len:]

        logits, _ = self(text_wdw) #  1, 1, vocab_size

        logits = logits[:, -1, :] / temperature # 1, vocab_size

        if top_p:
          probs = torch.softmax(logits, dim=-1)  #b, vocab
          sorted_probs, sorted_indices = torch.sort(probs, dim=-1, descending=True)
          cum_probs = torch.cumsum(sorted_probs, dim=-1)

          indices_to_remove = cum_probs > top_p
          indices_to_remove[:, 1:] = indices_to_remove[:, :-1].clone()
          indices_to_remove[..., 0] = False

          top_p_mask = torch.zeros_like(logits, dtype=bool, device=logits.device)
          for b in range(logits.size(0)):
            remove_indices = sorted_indices[b][indices_to_remove[b]]
            top_p_mask[b, remove_indices] = True
          logits[top_p_mask] = float('-inf')

        if top_k:
          v, _ = torch.topk(logits, min(self.vocab_size, top_k)) # B, top_k  #prevent top_k > vocab_size
          logits[logits < v[:, [-1]]] = float('-inf') # only keep top_k values

        if min_p:
          max_logit = torch.max(logits, dim=-1, keepdim=True).values
          threshold = max_logit + torch.log(torch.tensor(min_p, device=logits.device, dtype=logits.dtype))
          logits[logits < threshold] = float('-inf')

        probs = torch.softmax(logits, dim=-1) #1, vocab_size
        if greedy == True:
          next_token = torch.argmax(probs, dim=-1, keepdim=True) #useful for evaluation
        else:
          next_token = torch.multinomial(probs, num_samples=1) #1, 1

        if next_token == eos_id: # more general
          break

        text_ids = torch.cat((text_ids, next_token), dim=1)
        response = torch.cat([response, next_token], dim=1)
    return text_ids, response

# %%
wandb_log = True # for logging metrics to wandb

# %%
from torch.cuda.amp import GradScaler, autocast
import wandb
from torch.nn.utils import clip_grad_norm_
from contextlib import nullcontext
import numpy as np
import os

# %%
from dataclasses import dataclass
import torch
import time

# %%
# mount drive to save the tokenizer and dataset there
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# dataset and tokenization

# %%
# !pip install tokenizers datasets
# Out:
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.11/dist-packages (0.21.1)
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.11/dist-packages (from tokenizers) (0.30.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.4/491.4 kB 11.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 14.5 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 13.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 15.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2025.3.0 which is incompatible.
# Successfully installed datasets-3.5.1 dill-0.3.8 fsspec-2025.3.0 multiprocess-0.70.16 xxhash-3.5.0

# %%
from tokenizers import Tokenizer
from tokenizers.models import BPE # we use BPE tokenizer
from tokenizers.pre_tokenizers import Whitespace
from tokenizers.trainers import BpeTrainer

from datasets import load_dataset
from tqdm import tqdm

# %%
tokenizer = Tokenizer(BPE(unk_token="[UNK]"))

tokenizer.pre_tokenizer = Whitespace()

# %%
dataset = load_dataset("roneneldan/TinyStories") # just the first run. Then we save it, especially for huge datasets
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# (…)-00000-of-00004-2d5a1467fff1081b.parquet:   0%|          | 0.00/249M [00:00<?, ?B/s]
# (…)-00001-of-00004-5852b56a2bd28fd9.parquet:   0%|          | 0.00/248M [00:00<?, ?B/s]
# (…)-00002-of-00004-a26307300439e943.parquet:   0%|          | 0.00/246M [00:00<?, ?B/s]
# (…)-00003-of-00004-d243063613e5a057.parquet:   0%|          | 0.00/248M [00:00<?, ?B/s]
# (…)-00000-of-00001-869c898b519ad725.parquet:   0%|          | 0.00/9.99M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2119719 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/21990 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 2119719
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 21990
#     })
# })

# %%
dataset['train']['text'][0] # grab te first story, just to see what the data looks like
# Out:
# 'One day, a little girl named Lily found a needle in her room. She knew it was difficult to play with it because it was sharp. Lily wanted to share the needle with her mom, so she could sew a button on her shirt.\n\nLily went to her mom and said, "Mom, I found this needle. Can you share it with me and sew my shirt?" Her mom smiled and said, "Yes, Lily, we can share the needle and fix your shirt."\n\nTogether, they shared the needle and sewed the button on Lily\'s shirt. It was not difficult for them because they were sharing and helping each other. After they finished, Lily thanked her mom for sharing the needle and fixing her shirt. They both felt happy because they had shared and worked together.'

# %%
def batch_iterator():
    for story in dataset['train']['text']:
        yield story

trainer = BpeTrainer(
    vocab_size=6000,  # Adjust vocab_size as needed
    special_tokens=["<unk>", "<EOS>"],
    min_frequency=2,
    show_progress=True,
)

# %%
tokenizer.train_from_iterator(batch_iterator(), trainer)

tokenizer.save("drive/MyDrive/tinystories_bpe_tokenizer.json") # just once

# %%
tokenizer.encode("<EOS>").ids

# %%
def process_tokens(example):
  token_ids = tokenizer.encode(example['text'] + '<EOS>').ids

  return {'tokens': token_ids, 'len': len(token_ids)}

# %%
tokenized = dataset.map(process_tokens, remove_columns=['text']) # just the first run
# Out:
# Map:   0%|          | 0/2119719 [00:00<?, ? examples/s]
# Map:   0%|          | 0/21990 [00:00<?, ? examples/s]

# %%
# save the data as memory map
for split, data in tokenized.items():
  filename = f"drive/MyDrive/tokenized_stories_{split}.bin"
  dtype = np.uint16
  arr_length = np.sum(data['len'], dtype=np.uint64)
  arr = np.memmap(filename, dtype=dtype, mode = 'w+', shape=(arr_length,))
  num_shards = 5

  idx = 0
  for batch_idx in tqdm(range(num_shards), desc='writing to shards'):
    batch = data.shard(num_shards, index=batch_idx, contiguous=True)
    tokens = np.concatenate(batch['tokens']) #concatenate tokens from all rows
    arr[idx:idx+len(tokens)] = tokens
    idx = len(tokens)
  arr.flush()

# %%
tokenized.save_to_disk('/content/drive/MyDrive/tokenized_stories_dataset')

# %%
#Load the tokenizer and tokenized dataset, after having saved them

from datasets import load_from_disk

tokenizer = Tokenizer.from_file("drive/MyDrive/tinystories_bpe_tokenizer.json")
tokenized = load_from_disk('/content/drive/MyDrive/tokenized_stories_dataset')

# %% [markdown]
# Hyperparameters

# %%
@dataclass
class GPTConfig:
  n_head : int = 8
  dropout : int = 0.2
  vocab_size : int = 6000
  n_embed : int = 512
  n_layers : int = 8
  seq_len : int = 512
  bias : bool = False
  layernorm : bool = False
  mlp : bool = False

# %%
@dataclass
class TrainningConfig:
  learning_rate : float = 6e-4
  max_iters : int = 30000
  weight_decay: float = 1e-1
  beta1: float = 0.9
  beta2: float = 0.95

  grad_clip: float = 1.0
  warmup_steps = 1000
  max_decay_iter: int = 30000
  min_lr: float = 6e-5
  decay_r = True

  eval_interval: int = 100
  log_interval: int = 10
  eval_iters: int = 200
  gradient_accumulation_steps: int = 4
  batch_size: int = 128

  compile : bool = True

# %%
torch.manual_seed(43) # for reproducibility
torch.backends.cuda.matmul.allow_tf32 = True
torch.backends.cudnn.allow_tf32 = True

# %% [markdown]
# Set up our device and data type

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
if device == "cuda":
  compute_capability = torch.cuda.get_device_capability(0)[0]
  if compute_capability >= 8: #torch.cuda.is_bf16_supported():
    dtype = 'bfloat16'
    pdtype = torch.bfloat16
  else:
    dtype = 'float16'
    pdtype = torch.float16
else:
  dtype = 'float32'
  pdtype = torch.float32

print(f"device: {device}")
print(f"using dtype: {dtype}")
ctx = nullcontext() if device == 'cpu' else torch.amp.autocast(device_type=device, dtype=pdtype) # auto-mixed precision

# %%
wandb.login() # log our metrics to weights & biases (wandb)

# %%
wandb.init(project="Sidy_GPT", name="Sidy_GPT_tranning", resume=True)

# %%
# get the learning rate at each step
def get_lr(it):
  warmup = TrainningConfig.warmup_steps
  max_decay_iter = TrainningConfig.max_decay_iter
  min_lr = TrainningConfig.min_lr
  learning_rate = TrainningConfig.learning_rate

  if it < warmup:
    return TrainningConfig.learning_rate * (it + 1)/(warmup + 1)
  if it > max_decay_iter:
    return min_lr
  decay_ratio = (it - warmup) / (max_decay_iter - warmup)
  coef = 0.5 * (1.0 + math.cos(math.pi * decay_ratio))
  return min_lr + coef * (learning_rate - min_lr)

# %%
# poor man's dataloader
def get_batch(split, batch_size=TrainningConfig.batch_size, seq_len=GPTConfig.seq_len, device=device):
  filename = f"drive/MyDrive/tokenized_stories_{split}.bin"
  data = np.memmap(filename, dtype=np.uint16, mode='r')
  idxs = torch.randint(len(data) - seq_len, (batch_size,))
  x = torch.stack([torch.from_numpy((data[i:i+seq_len]).astype(np.int64)) for i in idxs])
  y = torch.stack([torch.from_numpy((data[i+1:i+1+seq_len]).astype(np.int64)) for i in idxs])

  if device == 'cuda':
     x, y = x.pin_memory().to(device, non_blocking=True), y.pin_memory().to(device, non_blocking=True)
  else:
    x = x.to(device)
    y = y.to(device)

  return x, y

# %%
@torch.no_grad
def estimate_loss(model, eval_iters):
  model.eval()
  out = {}
  for split in ['train', 'validation']:
    losses = torch.zeros(eval_iters)
    for k in range(eval_iters):
      X, Y = get_batch('validation')
      with ctx:
        logits, loss = model(X, Y)
      losses[k] = loss
    out[split] = losses.mean()
  model.train()
  return out

# %%
model_args = dict(
    n_head = GPTConfig.n_head,
    n_embed = GPTConfig.n_embed,
    n_layers = GPTConfig.n_layers,
    seq_len = GPTConfig.seq_len,
    vocab_size = GPTConfig.vocab_size,
    dropout = GPTConfig.dropout,
    bias = GPTConfig.bias,
    mlp = GPTConfig.mlp,
)

# %%
iter_num = 0
best_val_loss = 1e9
always_save_checkpoint = True
chkpt_path = 'drive/MyDrive/chkpt.pt'

# %%
def load_model(chkpt_path, device):
  resume = False
  best_val_loss = 1e9
  iter_num = 0
  checkpoint = None
  if os.path.exists(chkpt_path): # my drive
    checkpoint = torch.load(chkpt_path, map_location=device)
    gpt_conf = GPTConfig(**checkpoint["model_args"])
    model = GPT(gpt_conf)
    state_dict = checkpoint['model']
    unwanted_prefix = '_orig_mod.'

    #get rid of this weird prefix
    for k, v in list(state_dict.items()):
      if k.startswith(unwanted_prefix):
        state_dict[k[len(unwanted_prefix): ]] = state_dict.pop(k)

    model.load_state_dict(state_dict)
    iter_num = checkpoint['iter_num']
    best_val_loss = checkpoint['best_val_loss']
    num_tokens = checkpoint['num_tokens']
    resume = True
    print(f"trainning Resumed from {iter_num} steps with {best_val_loss} as best_val_loss.")
  else:
    model = GPT(GPTConfig)
    print(f"Starting from scratch from step {iter_num}")
  model.to(device)
  return model, resume, iter_num, num_tokens, best_val_loss, checkpoint

# %%
tokens_per_iter = TrainningConfig.gradient_accumulation_steps * TrainningConfig.batch_size * GPTConfig.seq_len

print(f"tokens per iteration will be {tokens_per_iter}") # you can stop trainning based on the total number of tokens processed

# %% [markdown]
# Trainning function

# %%
def train_GPT(TrainningConfig, device, chkpt_path):
  model, resume, iter_num, num_tokens, best_val_loss, checkpoint = load_model(chkpt_path, device)
  num_params = model.get_num_params()
  print(f"Number of parameters {num_params/1e6}M params")

  # if ddp:
  #   model = DDP(model, )
  model.train()

  optimizer = model.configure_optimizers(TrainningConfig.weight_decay, TrainningConfig.learning_rate, betas=(TrainningConfig.beta1, TrainningConfig.beta2))
  if resume == True:
    optimizer.load_state_dict(checkpoint['optimizer'])

  scaler = torch.GradScaler(enabled=(dtype=='float16'))

  if TrainningConfig.compile:
    print("compiling model...")
    #unoptimized_model = model
    model = torch.compile(model)

  running_mfu = -1.0
  acc_loss = 0
  t0 = time.time()
  local_iter = 0 # iteration of the loop
  while True:
    # get the lr
    lr = get_lr(iter_num) if TrainningConfig.decay_r else TrainningConfig.learning_rate
    for param_group in optimizer.param_groups:
      param_group['lr'] = lr

    X, Y = get_batch("train")

    if iter_num % TrainningConfig.eval_interval == 0:
      losses = estimate_loss(model, TrainningConfig.eval_iters)
      print(f"step: {iter_num}, train_loss: {losses['train']}, eval_loss: {losses['validation']}")
      # wandb logging
      if wandb_log:
        wandb.log({
            "iter_num": iter_num,
            "train_loss" : losses['train'],
            "val_loss": losses['validation'],
            "model_args": model_args,
            "learning_rate": lr,
            "running_mfu": running_mfu*100,
            "num_tokens": num_tokens
        }, step=iter_num)
      if losses['validation'] < best_val_loss or always_save_checkpoint:
        checkpoint = {
            "model": model.state_dict(),
            "optimizer": optimizer.state_dict(),
            "model_args": model_args,
            "iter_num": iter_num,
            "best_val_loss": best_val_loss,
            "num_tokens": num_tokens
        }
        best_val_loss = losses['validation']
        print(f'saving checkpoint to {chkpt_path}...')
        torch.save(checkpoint, chkpt_path)
        model.eval()
        prompt = "once upon a time"
        ids = tokenizer.encode(prompt).ids
        ids = torch.tensor(ids, dtype=torch.int64, device=device).unsqueeze(0)
        _, response = model.generate(ids, max_samples=256, temperature=1.0)
        print(f"Generated story:\n -- {tokenizer.decode(response.squeeze(0).tolist())} --")
        if wandb_log:
          wandb.log({
             "story": response
         })
        model.train()

    for microstep in range(TrainningConfig.gradient_accumulation_steps):
        with ctx:
          logits, loss = model(X, Y)
          loss = loss / TrainningConfig.gradient_accumulation_steps
        acc_loss += loss
        X, Y = get_batch('train') # prefetch, while GPU doing backprop
        scaler.scale(loss).backward() # pytorch accumulates gradients automatically

    if TrainningConfig.grad_clip != 0:
        scaler.unscale_(optimizer)
        torch.nn.utils.clip_grad_norm_(model.parameters(), TrainningConfig.grad_clip)
    scaler.step(optimizer)
    scaler.update()

    optimizer.zero_grad(set_to_none=True)

    t1 = time.time()
    dt = t1 - t0
    t0 = t1

    if iter_num % TrainningConfig.log_interval == 0:
      if iter_num >=5: #no mfu in the first 5 iterations
         mfu = model.estimate_mfu(TrainningConfig.batch_size * TrainningConfig.gradient_accumulation_steps, dt)
         running_mfu = mfu  #you can do if running_mfu ==-1.0 else 0.4*running_mfu + 0.6*mfu
      print(f"iteration step {iter_num}, loss {acc_loss:.4f}, time {dt*1000:.2f} ms, mfu {running_mfu*100:.2f} %")
      print(f"tokens processed {num_tokens}")

    num_tokens += tokens_per_iter
    iter_num += 1
    local_iter +=1
    acc_loss = 0

    if  iter_num == TrainningConfig.max_iters:
      break

# %%
train_GPT(TrainningConfig, device, chkpt_path)
# Out:
# trainning Resumed from 6100 steps with 0.6517184376716614 as best_val_loss.
# Number of parameters 28.242432M params
# number of non decay params: 28495872
# number of non decay params: 8704
# compiling model...
# step: 6100, train_loss: 0.6513611674308777, eval_loss: 0.6507238745689392
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , a little girl named Emmy heard a big decision . She would be very envious of the coin she had seen earlier . Emmy was determined to learn how to reach a coin , so she decided to ask her parents . She walked up to the coin , which was about to half across the finish line . She saw a big man working on some very hard work . Emmy asked him if he could help . The man told his name was Joe and that he can help . So , each day , Joe and Emmy worked together to reach for the coin . Sometimes , Joe brought out apples and re jo iced in the meadow . It was such a nice way to prevent getting the coin or lost it . Eventually , Carl and Emmy sh own that if you work together , you can reach the coin ." Lily felt proud of her achieve ment . She was never too envious when she saw Carl ride a coin again . Sarah had learned a valuable lesson about yield ing to your lim its and gathering the peanuts . --
# wandb: WARNING Tried to log to step 6100 that is less than the current step 6101. Steps must be monotonically increasing, so this data will be ignored. See https://wandb.me/define-metric to log data out of order.
# iteration step 6100, loss 0.6540, time 70494.68 ms, mfu 0.60 %
# tokens processed 1535792128
# iteration step 6110, loss 0.6922, time 2040.65 ms, mfu 20.83 %
# tokens processed 1538413568
# iteration step 6120, loss 0.6487, time 2080.14 ms, mfu 20.44 %
# tokens processed 1541035008
# iteration step 6130, loss 0.6294, time 2079.07 ms, mfu 20.45 %
# tokens processed 1543656448
# iteration step 6140, loss 0.6474, time 2079.53 ms, mfu 20.44 %
# tokens processed 1546277888
# iteration step 6150, loss 0.7176, time 2059.40 ms, mfu 20.64 %
# tokens processed 1548899328
# iteration step 6160, loss 0.7112, time 2058.05 ms, mfu 20.66 %
# tokens processed 1551520768
# iteration step 6170, loss 0.6587, time 2080.61 ms, mfu 20.43 %
# tokens processed 1554142208
# iteration step 6180, loss 0.7149, time 2051.59 ms, mfu 20.72 %
# tokens processed 1556763648
# iteration step 6190, loss 0.6919, time 2079.52 ms, mfu 20.44 %
# tokens processed 1559385088
# step: 6200, train_loss: 0.6448690295219421, eval_loss: 0.6485092639923096
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a kind camp . It was on the other side of the cave , so no one knew where it was . One day , a big storm appeared . It was very hot outside , so the forest staff ran into it to find a cozy spot . They found a big warm spot and stayed there for a long time . It felt better there too . When the storm last ed , it was safe again . The birds , squirrels and animals were so happy to be together . The kind camp was reminded of the kind hut . The end . --
# iteration step 6200, loss 0.6900, time 65358.21 ms, mfu 0.65 %
# tokens processed 1562006528
# iteration step 6210, loss 0.6712, time 2079.40 ms, mfu 20.45 %
# tokens processed 1564627968
# iteration step 6220, loss 0.6681, time 2079.81 ms, mfu 20.44 %
# tokens processed 1567249408
# iteration step 6230, loss 0.6352, time 2059.51 ms, mfu 20.64 %
# tokens processed 1569870848
# iteration step 6240, loss 0.6841, time 2016.53 ms, mfu 21.08 %
# tokens processed 1572492288
# iteration step 6250, loss 0.7335, time 2053.13 ms, mfu 20.71 %
# tokens processed 1575113728
# iteration step 6260, loss 0.6325, time 2079.34 ms, mfu 20.45 %
# tokens processed 1577735168
# iteration step 6270, loss 0.6120, time 2058.82 ms, mfu 20.65 %
# tokens processed 1580356608
# iteration step 6280, loss 0.6661, time 2058.88 ms, mfu 20.65 %
# tokens processed 1582978048
# iteration step 6290, loss 0.6417, time 2056.10 ms, mfu 20.68 %
# tokens processed 1585599488
# step: 6300, train_loss: 0.6439099311828613, eval_loss: 0.647318422794342
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- there was a boy named John . John was very . He was always very successful at school . Every morning when school the day came , he would run to his classroom . He would read and write in the classroom until it was seven hours . One day John asked his teacher , " Can I get some fruit ?" His teacher said " Yes , let ' s get some fruit ". John was very happy . He managed to get some fruit and he ate it fast . Then Mommy : " Oh baby boy , you did an amazing job !" John was so proud of himself . He had managed to get enough fruit and he smiled every day at school . --
# iteration step 6300, loss 0.7029, time 65509.16 ms, mfu 0.65 %
# tokens processed 1588220928
# iteration step 6310, loss 0.6910, time 2068.89 ms, mfu 20.55 %
# tokens processed 1590842368
# iteration step 6320, loss 0.7003, time 2078.84 ms, mfu 20.45 %
# tokens processed 1593463808
# iteration step 6330, loss 0.6861, time 2058.10 ms, mfu 20.66 %
# tokens processed 1596085248
# iteration step 6340, loss 0.7124, time 2043.44 ms, mfu 20.81 %
# tokens processed 1598706688
# iteration step 6350, loss 0.7038, time 2050.15 ms, mfu 20.74 %
# tokens processed 1601328128
# iteration step 6360, loss 0.7402, time 2058.86 ms, mfu 20.65 %
# tokens processed 1603949568
# iteration step 6370, loss 0.7479, time 2080.48 ms, mfu 20.44 %
# tokens processed 1606571008
# iteration step 6380, loss 0.6857, time 2057.16 ms, mfu 20.67 %
# tokens processed 1609192448
# iteration step 6390, loss 0.6561, time 2059.01 ms, mfu 20.65 %
# tokens processed 1611813888
# step: 6400, train_loss: 0.6385931968688965, eval_loss: 0.6352890133857727
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl named Lily . She had velvet coats that she loved to wear . One day , she went outside to play in the yard . As she was playing , she saw a branch on the tree and picked it up . " Look , mommy ! This branch says I need to attach I found ," she said . Her mommy replied , " That ' s great , Lily ! But what about it when you fold it ?" Lily recognized that she had found a little treasure hidden under the tree . She was so happy that she found it . Later that day , Lily went inside to cook dinner . But as her mommy was cooking , she realized that the branch was rot ting . She said , " Oh no , the branch is rot ting . We need to keep it healthy ." Lily felt sad and knew that just what to do . She decided to put the rock back in the tree and wear it whenever she wanted to play . The end . --
# iteration step 6400, loss 0.6975, time 65855.26 ms, mfu 0.65 %
# tokens processed 1614435328
# iteration step 6410, loss 0.7010, time 2064.45 ms, mfu 20.59 %
# tokens processed 1617056768
# iteration step 6420, loss 0.7036, time 2079.15 ms, mfu 20.45 %
# tokens processed 1619678208
# iteration step 6430, loss 0.6719, time 2059.73 ms, mfu 20.64 %
# tokens processed 1622299648
# iteration step 6440, loss 0.6847, time 2056.27 ms, mfu 20.68 %
# tokens processed 1624921088
# iteration step 6450, loss 0.7095, time 2079.34 ms, mfu 20.45 %
# tokens processed 1627542528
# iteration step 6460, loss 0.6925, time 2076.38 ms, mfu 20.48 %
# tokens processed 1630163968
# iteration step 6470, loss 0.7029, time 2059.03 ms, mfu 20.65 %
# tokens processed 1632785408
# iteration step 6480, loss 0.6656, time 2063.85 ms, mfu 20.60 %
# tokens processed 1635406848
# iteration step 6490, loss 0.6343, time 2076.90 ms, mfu 20.47 %
# tokens processed 1638028288
# step: 6500, train_loss: 0.6484154462814331, eval_loss: 0.6440122723579407
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little boy named Jack . He had a toy car with a red cross on the top . One day , Jack was playing with his toys while he thought he might need a balance . He sh uff led his toy car down a drive way , but it didn ' t quite go very high . Jack was dis playing his toys when he heard a voice . " Hey Jack ! Don ' t be mad !" It was his dad . " Come back inside right now !" Jack took a deep breath and went inside . After his dad left , Jack opened the toy one more time and watched his dad balanced the cross in his hands . " See , Jack ? Sometimes , even if you have a lot of fun , you can always balance the cross in your hands . L ife can be left out and way up your goals ." Jack was so happy and proud of himself . He waved goodbye to his dad and said , " Thanks for a sunny day , I can ' t wait to play with my cars again !" --
# iteration step 6500, loss 0.7139, time 66143.03 ms, mfu 0.64 %
# tokens processed 1640649728
# iteration step 6510, loss 0.7291, time 2022.60 ms, mfu 21.02 %
# tokens processed 1643271168
# iteration step 6520, loss 0.6688, time 2079.05 ms, mfu 20.45 %
# tokens processed 1645892608
# iteration step 6530, loss 0.6601, time 2079.34 ms, mfu 20.45 %
# tokens processed 1648514048
# iteration step 6540, loss 0.7576, time 2041.87 ms, mfu 20.82 %
# tokens processed 1651135488
# iteration step 6550, loss 0.6523, time 2051.43 ms, mfu 20.72 %
# tokens processed 1653756928
# iteration step 6560, loss 0.7355, time 2079.72 ms, mfu 20.44 %
# tokens processed 1656378368
# iteration step 6570, loss 0.6547, time 2080.36 ms, mfu 20.44 %
# tokens processed 1658999808
# iteration step 6580, loss 0.6794, time 2059.94 ms, mfu 20.64 %
# tokens processed 1661621248
# iteration step 6590, loss 0.7222, time 2059.61 ms, mfu 20.64 %
# tokens processed 1664242688
# step: 6600, train_loss: 0.6401961445808411, eval_loss: 0.6469146609306335
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a big dinosaur . He was very big and strong . The dinosaur lived near the desert with his friends . One day , the dinosaur ran away from his home . The dinosaur went to the oasis to look for some food . When he got there , he found a big pile of leaves . He ate and ate until he was full . After that , the dinosaur started to get hungry . He needed to find some food . He looked for the big tree behind the trees , but he couldn ' t find any . The dinosaur looked and looked until he found a small pond . He drank the water and felt much happier . After eating , the dinosaur was very happy because he had lots of food to eat . He swam and played until the sun went down . From that day on , the dinosaur became known as the str ongest dinosaur in the land . --
# iteration step 6600, loss 0.6449, time 65966.23 ms, mfu 0.64 %
# tokens processed 1666864128
# iteration step 6610, loss 0.7080, time 2060.43 ms, mfu 20.63 %
# tokens processed 1669485568
# iteration step 6620, loss 0.7084, time 2078.88 ms, mfu 20.45 %
# tokens processed 1672107008
# iteration step 6630, loss 0.7481, time 2075.47 ms, mfu 20.48 %
# tokens processed 1674728448
# iteration step 6640, loss 0.7074, time 2060.30 ms, mfu 20.64 %
# tokens processed 1677349888
# iteration step 6650, loss 0.6427, time 2066.39 ms, mfu 20.57 %
# tokens processed 1679971328
# iteration step 6660, loss 0.6513, time 2055.51 ms, mfu 20.68 %
# tokens processed 1682592768
# iteration step 6670, loss 0.6256, time 2059.16 ms, mfu 20.65 %
# tokens processed 1685214208
# iteration step 6680, loss 0.6658, time 2080.18 ms, mfu 20.44 %
# tokens processed 1687835648
# iteration step 6690, loss 0.6715, time 2059.70 ms, mfu 20.64 %
# tokens processed 1690457088
# step: 6700, train_loss: 0.6360609531402588, eval_loss: 0.640022873878479
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a polite little girl named Lily . One day , Lily and her mom went to the park . At the park , there were swings and slides . Lily wanted to join with them , but her mom said she couldn ' t . Lily felt sad and wanted to go home . As they walked home , they saw a lady with a big bag of candy . Lily ' s mom explained that the candy was for later because it was her first time for a treat . Lily didn ' t want that to happen , but she knew it was a good choice . After they were done taking medicine , they went back to the park and played together . Eventually , it was time to go home . Lily was very tired but happy . She was glad she got to play with her mom at the park and see the candy that caught the bad smell . --
# iteration step 6700, loss 0.6612, time 65846.56 ms, mfu 0.65 %
# tokens processed 1693078528
# iteration step 6710, loss 0.6824, time 2057.08 ms, mfu 20.67 %
# tokens processed 1695699968
# iteration step 6720, loss 0.7091, time 2078.99 ms, mfu 20.45 %
# tokens processed 1698321408
# iteration step 6730, loss 0.6073, time 2058.76 ms, mfu 20.65 %
# tokens processed 1700942848
# iteration step 6740, loss 0.6345, time 2051.73 ms, mfu 20.72 %
# tokens processed 1703564288
# iteration step 6750, loss 0.5986, time 2058.40 ms, mfu 20.65 %
# tokens processed 1706185728
# iteration step 6760, loss 0.7045, time 2080.52 ms, mfu 20.44 %
# tokens processed 1708807168
# iteration step 6770, loss 0.7348, time 2079.65 ms, mfu 20.44 %
# tokens processed 1711428608
# iteration step 6780, loss 0.6827, time 2063.30 ms, mfu 20.61 %
# tokens processed 1714050048
# iteration step 6790, loss 0.6621, time 2061.03 ms, mfu 20.63 %
# tokens processed 1716671488
# step: 6800, train_loss: 0.6377421021461487, eval_loss: 0.6413430571556091
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a black bird who lived in a tree . Her name was Lilly and she loved to fly . One day , Lilly decided to visit her mommy and daddy . As she flew , she could see them fly high up in the sky . " Look , mommy !" Lilly said . " We are flying !" " Yes , they are ," her mommy said . " But we need to go home now ." Lilly pout ed and flapped her wings as she flew higher and higher . Suddenly , she felt something soft on her wings . She stopped and looked down , and saw a thin lay er of dust on the ground next to her . She couldn ' t help but smile . She realized that passing over was fun and she knew that she would never forget it . --
# iteration step 6800, loss 0.6733, time 65745.34 ms, mfu 0.65 %
# tokens processed 1719292928
# iteration step 6810, loss 0.6353, time 2018.63 ms, mfu 21.06 %
# tokens processed 1721914368
# iteration step 6820, loss 0.6957, time 2041.50 ms, mfu 20.83 %
# tokens processed 1724535808
# iteration step 6830, loss 0.6490, time 2059.74 ms, mfu 20.64 %
# tokens processed 1727157248
# iteration step 6840, loss 0.6809, time 2078.86 ms, mfu 20.45 %
# tokens processed 1729778688
# iteration step 6850, loss 0.6969, time 2059.53 ms, mfu 20.64 %
# tokens processed 1732400128
# iteration step 6860, loss 0.6380, time 2047.66 ms, mfu 20.76 %
# tokens processed 1735021568
# iteration step 6870, loss 0.7511, time 2079.76 ms, mfu 20.44 %
# tokens processed 1737643008
# iteration step 6880, loss 0.6672, time 2078.84 ms, mfu 20.45 %
# tokens processed 1740264448
# iteration step 6890, loss 0.7451, time 2059.52 ms, mfu 20.64 %
# tokens processed 1742885888
# step: 6900, train_loss: 0.638105571269989, eval_loss: 0.6395562887191772
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little fish who loved to swim . She splashed in the big blue sea with her friends . One day , her mom asked her to clean her room again because she was going to feel hungry . Lily said , " Okay , Mommy ! I will clean my room ." Her mom got a cloth and started to clean the room . After they finished cleaning , Lily ' s friend came over to play . They splashed and played until it was time to go home . Lily was happy . As they were leaving the room , Lily said , " Mommy , I love swimming in my clean room ." Her mom replied , " I love helping you , Lily . Now let ' s do something else tomorrow ." Lily smiled and closed her eyes . She dreamed of swimming again with her friends . --
# iteration step 6900, loss 0.6885, time 66326.73 ms, mfu 0.64 %
# tokens processed 1745507328
# iteration step 6910, loss 0.7088, time 1999.47 ms, mfu 21.26 %
# tokens processed 1748128768
# iteration step 6920, loss 0.7142, time 2042.97 ms, mfu 20.81 %
# tokens processed 1750750208
# iteration step 6930, loss 0.6386, time 2082.25 ms, mfu 20.42 %
# tokens processed 1753371648
# iteration step 6940, loss 0.6514, time 2068.55 ms, mfu 20.55 %
# tokens processed 1755993088
# iteration step 6950, loss 0.6417, time 2059.18 ms, mfu 20.65 %
# tokens processed 1758614528
# iteration step 6960, loss 0.6155, time 2079.90 ms, mfu 20.44 %
# tokens processed 1761235968
# iteration step 6970, loss 0.6622, time 2078.69 ms, mfu 20.45 %
# tokens processed 1763857408
# iteration step 6980, loss 0.6772, time 2058.52 ms, mfu 20.65 %
# tokens processed 1766478848
# iteration step 6990, loss 0.6044, time 2058.84 ms, mfu 20.65 %
# tokens processed 1769100288
# step: 7000, train_loss: 0.6428213715553284, eval_loss: 0.6393159627914429
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- in a far away land , there was a little girl named Lily . She loved playing with her toys and going on adventures with her friends . One day , her mom told her that they were going on a picnic because they would get a pizza for lunch . Lily was so happy ! She helped her mom pack all the important things they needed in the car light er . When they arrived at the park , Lily saw a big , red tractor parked on the road . She asked her mom why the driver was there . Her mom explained that the driver was there to load some snacks for the kids to eat . Lily said she loved picnic s because she had so much fun playing with her friends . Her mom said that she could have a picnic for them too . They all ate lots of tasty snacks and had a wonderful time together . --
# iteration step 7000, loss 0.6344, time 65923.38 ms, mfu 0.64 %
# tokens processed 1771721728
# iteration step 7010, loss 0.6943, time 2017.66 ms, mfu 21.07 %
# tokens processed 1774343168
# iteration step 7020, loss 0.6361, time 2078.85 ms, mfu 20.45 %
# tokens processed 1776964608
# iteration step 7030, loss 0.7115, time 2078.94 ms, mfu 20.45 %
# tokens processed 1779586048
# iteration step 7040, loss 0.6316, time 2057.04 ms, mfu 20.67 %
# tokens processed 1782207488
# iteration step 7050, loss 0.6996, time 2059.35 ms, mfu 20.65 %
# tokens processed 1784828928
# iteration step 7060, loss 0.6481, time 2061.09 ms, mfu 20.63 %
# tokens processed 1787450368
# iteration step 7070, loss 0.6827, time 2059.71 ms, mfu 20.64 %
# tokens processed 1790071808
# iteration step 7080, loss 0.6061, time 2075.71 ms, mfu 20.48 %
# tokens processed 1792693248
# iteration step 7090, loss 0.7409, time 2063.52 ms, mfu 20.60 %
# tokens processed 1795314688
# step: 7100, train_loss: 0.639819860458374, eval_loss: 0.6465070843696594
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a big , beautiful house with lots of nice things to play with . One day , the house was very angry because nobody owned it . It kept arguing with its family and it didn ' t want everyone to return . Everyone was sad and the house didn ' t understand why . A brave little girl named Sarah went up to the house . She asked , " What ' s wrong with the house ?". The girl smiled and said , " I ' m a guard that delivered things in the house . They ' re not available anymore and I don ' t know what to do with them ". Sarah smiled and said , " That ' s ok . I ' ll be right to lend you something bright and pretty to play with . I recommend it to you !" The girl was happy and they spent the rest of the day playing with the guard and making sure the house was always closed . Soon enough , the house was full of it and it was even happier than before . From then on , the girl and the guard were good friends , and they always had fun together . --
# iteration step 7100, loss 0.6631, time 66008.35 ms, mfu 0.64 %
# tokens processed 1797936128
# iteration step 7110, loss 0.6449, time 2019.43 ms, mfu 21.05 %
# tokens processed 1800557568
# iteration step 7120, loss 0.7044, time 2058.77 ms, mfu 20.65 %
# tokens processed 1803179008
# iteration step 7130, loss 0.6913, time 2048.16 ms, mfu 20.76 %
# tokens processed 1805800448
# iteration step 7140, loss 0.6154, time 2055.45 ms, mfu 20.68 %
# tokens processed 1808421888
# iteration step 7150, loss 0.6653, time 2059.39 ms, mfu 20.64 %
# tokens processed 1811043328
# iteration step 7160, loss 0.6181, time 2062.72 ms, mfu 20.61 %
# tokens processed 1813664768
# iteration step 7170, loss 0.7124, time 2079.48 ms, mfu 20.45 %
# tokens processed 1816286208
# iteration step 7180, loss 0.7277, time 2079.02 ms, mfu 20.45 %
# tokens processed 1818907648
# iteration step 7190, loss 0.6518, time 2079.31 ms, mfu 20.45 %
# tokens processed 1821529088
# step: 7200, train_loss: 0.638520359992981, eval_loss: 0.6292546987533569
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl named Lily . She loved to play with her dolls and dolls all day long . One day , Lily ' s mommy took her to a park where they met a big dog . Lily was scared of the big dog , but her mommy made a promise to make her feel safe . Lily and her mommy went to the meeting and ate cookies . After they talked , Lily noticed that the dog was wag ling and feeling rough . She decided to turn around and go play on the swings instead . When they got home , Lily told her daddy about the big dog and how she went with her mommy to the park . They decided to go on a walk together and go on a bumpy ride . They had so much fun and Lily was happy that she promised herself that she would always promise to her mommy to keep her prom ises . The end . --
# iteration step 7200, loss 0.7201, time 65726.76 ms, mfu 0.65 %
# tokens processed 1824150528
# iteration step 7210, loss 0.6590, time 2048.22 ms, mfu 20.76 %
# tokens processed 1826771968
# iteration step 7220, loss 0.7222, time 2059.25 ms, mfu 20.65 %
# tokens processed 1829393408
# iteration step 7230, loss 0.6308, time 2079.16 ms, mfu 20.45 %
# tokens processed 1832014848
# iteration step 7240, loss 0.6599, time 2054.68 ms, mfu 20.69 %
# tokens processed 1834636288
# iteration step 7250, loss 0.6601, time 2054.24 ms, mfu 20.70 %
# tokens processed 1837257728
# iteration step 7260, loss 0.6812, time 2049.71 ms, mfu 20.74 %
# tokens processed 1839879168
# iteration step 7270, loss 0.6434, time 2050.88 ms, mfu 20.73 %
# tokens processed 1842500608
# iteration step 7280, loss 0.7221, time 2059.62 ms, mfu 20.64 %
# tokens processed 1845122048
# iteration step 7290, loss 0.6692, time 2052.38 ms, mfu 20.72 %
# tokens processed 1847743488
# step: 7300, train_loss: 0.6283938884735107, eval_loss: 0.6252734661102295
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little dog named Max . Max loved to run and play outside . One day , Max ' s owner took him to the veterinarian who gave Max some medicine . Max didn ' t like the medicine because it was hard . He didn ' t like it at all and made dogs run away . Suddenly , one of the mailman ' s dogs stopped running and asked the mailman to repeat the same words : " deaf people ". The mailman repeated the same words : " deaf people don ' t understand Max , they do silly things !". Max ' s owner was surprised and happy . From that day on , Max kept the dog in the veterinarian ' s office and they all played together happily ever after . --
# iteration step 7300, loss 0.6718, time 65565.24 ms, mfu 0.65 %
# tokens processed 1850364928
# iteration step 7310, loss 0.6264, time 2027.75 ms, mfu 20.97 %
# tokens processed 1852986368
# iteration step 7320, loss 0.6623, time 2049.10 ms, mfu 20.75 %
# tokens processed 1855607808
# iteration step 7330, loss 0.6944, time 2042.36 ms, mfu 20.82 %
# tokens processed 1858229248
# iteration step 7340, loss 0.6442, time 2035.13 ms, mfu 20.89 %
# tokens processed 1860850688
# iteration step 7350, loss 0.6182, time 2049.93 ms, mfu 20.74 %
# tokens processed 1863472128
# iteration step 7360, loss 0.7302, time 2059.52 ms, mfu 20.64 %
# tokens processed 1866093568
# iteration step 7370, loss 0.6902, time 2079.25 ms, mfu 20.45 %
# tokens processed 1868715008
# iteration step 7380, loss 0.6957, time 2062.75 ms, mfu 20.61 %
# tokens processed 1871336448
# iteration step 7390, loss 0.6564, time 2059.36 ms, mfu 20.65 %
# tokens processed 1873957888
# step: 7400, train_loss: 0.6426913738250732, eval_loss: 0.6343409419059753
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little boy named Timmy . Timmy loved to draw with his crayons . One day , Timmy ' s friend Billy brought some pepper on his lunch . Timmy was so happy and he ate the pepper quickly . Billy also shared his pepper with Timmy and they both loved it . But then , Billy accidentally dropped some butter on Timmy ' s shirt . Timmy got very upset and he said sorry to Billy . Billy forgave Timmy and they could draw together with the crayons some more . From that day on , Timmy learned that sharing is important and it ' s good to share . He also learned that playing with his toys was much more fun than spending too much more time alone . --
# iteration step 7400, loss 0.6454, time 65504.65 ms, mfu 0.65 %
# tokens processed 1876579328
# iteration step 7410, loss 0.6609, time 2053.46 ms, mfu 20.70 %
# tokens processed 1879200768
# iteration step 7420, loss 0.6505, time 2079.51 ms, mfu 20.44 %
# tokens processed 1881822208
# iteration step 7430, loss 0.7714, time 2031.76 ms, mfu 20.93 %
# tokens processed 1884443648
# iteration step 7440, loss 0.7025, time 2036.05 ms, mfu 20.88 %
# tokens processed 1887065088
# iteration step 7450, loss 0.6866, time 2046.61 ms, mfu 20.77 %
# tokens processed 1889686528
# iteration step 7460, loss 0.6743, time 2059.19 ms, mfu 20.65 %
# tokens processed 1892307968
# iteration step 7470, loss 0.6536, time 2078.99 ms, mfu 20.45 %
# tokens processed 1894929408
# iteration step 7480, loss 0.7324, time 2058.94 ms, mfu 20.65 %
# tokens processed 1897550848
# iteration step 7490, loss 0.6533, time 2071.64 ms, mfu 20.52 %
# tokens processed 1900172288
# step: 7500, train_loss: 0.6317011713981628, eval_loss: 0.6285780072212219
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little monkey named Sara . Sara was very intelligent . She knew many things in the jungle . One day , she found a shiny silver razor in the ground . She found it and wanted to show it to her friends . Sara showed the knife to her friends and they all learned about the sharp weapon . They wanted to know more about the razor . They all worked together and looked at the shiny shiny object . They were very happy . If Sara found anything in the jungle , she would help them find it . The hidden toy became where the shiny thing was . --
# iteration step 7500, loss 0.6696, time 65483.07 ms, mfu 0.65 %
# tokens processed 1902793728
# iteration step 7510, loss 0.6259, time 2046.13 ms, mfu 20.78 %
# tokens processed 1905415168
# iteration step 7520, loss 0.6749, time 2080.02 ms, mfu 20.44 %
# tokens processed 1908036608
# iteration step 7530, loss 0.6595, time 2078.76 ms, mfu 20.45 %
# tokens processed 1910658048
# iteration step 7540, loss 0.6699, time 2048.96 ms, mfu 20.75 %
# tokens processed 1913279488
# iteration step 7550, loss 0.5888, time 2059.65 ms, mfu 20.64 %
# tokens processed 1915900928
# iteration step 7560, loss 0.7054, time 2059.64 ms, mfu 20.64 %
# tokens processed 1918522368
# iteration step 7570, loss 0.6526, time 2059.55 ms, mfu 20.64 %
# tokens processed 1921143808
# iteration step 7580, loss 0.6890, time 2063.08 ms, mfu 20.61 %
# tokens processed 1923765248
# iteration step 7590, loss 0.6553, time 2067.98 ms, mfu 20.56 %
# tokens processed 1926386688
# step: 7600, train_loss: 0.6330069899559021, eval_loss: 0.6366879343986511
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl named Lulu . She loved wearing bright clothes and had long , shiny shoes . But Lulu was scared of the dark . Every time she went on an adventure , she would bring her orange boots with her . Th ough it felt dark outside , Lulu knew she could trust her smelly boots to stay warm . But one day , Lulu wanted to show off her boots to all of her friends . She jumped up and down in the yard and all her friends were so surprised . They all laughed and started running together , but Lulu was just as excited as her friends said . Lulu realized how brave her boots felt to give off their eyes , and the friends all went to have adventure ! From then on , every time Lulu went on an adventure , her boots could always bring her back up in front of her when she chuckled . She and her red boots were the best of friends , and they were so excited to go out on many adventures together . --
# iteration step 7600, loss 0.6634, time 66601.00 ms, mfu 0.64 %
# tokens processed 1929008128
# iteration step 7610, loss 0.6679, time 2042.89 ms, mfu 20.81 %
# tokens processed 1931629568
# iteration step 7620, loss 0.6510, time 2049.25 ms, mfu 20.75 %
# tokens processed 1934251008
# iteration step 7630, loss 0.6557, time 2035.27 ms, mfu 20.89 %
# tokens processed 1936872448
# iteration step 7640, loss 0.6913, time 2024.89 ms, mfu 21.00 %
# tokens processed 1939493888
# iteration step 7650, loss 0.6538, time 2033.16 ms, mfu 20.91 %
# tokens processed 1942115328
# iteration step 7660, loss 0.7254, time 2032.63 ms, mfu 20.92 %
# tokens processed 1944736768
# iteration step 7670, loss 0.7021, time 2038.43 ms, mfu 20.86 %
# tokens processed 1947358208
# iteration step 7680, loss 0.7364, time 2056.05 ms, mfu 20.68 %
# tokens processed 1949979648
# iteration step 7690, loss 0.6649, time 2058.59 ms, mfu 20.65 %
# tokens processed 1952601088
# step: 7700, train_loss: 0.6328856348991394, eval_loss: 0.6370145678520203
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl named Lily . She had a brother named Jack . One day , they were playing hide and seek in their house . When they were hiding , Jack seemed sad and left Lily alone . Jill asked , " Are you okay , Jack ?" Jack said , " No , I don ' t feel fine . I want to go back to my house ." Lily said , " Don ' t be scared , Jack . I ' ll count to ten and you ' ll seek with me ." Jack smiled and counted to ten . He counted to ten and then said , " I ' m done !" He replied , " Now you ' re my friend ." Lily smiled and said , " You ' re my best friend , Jack ." --
# iteration step 7700, loss 0.6536, time 65683.97 ms, mfu 0.65 %
# tokens processed 1955222528
# iteration step 7710, loss 0.6852, time 2057.22 ms, mfu 20.67 %
# tokens processed 1957843968
# iteration step 7720, loss 0.7234, time 2079.91 ms, mfu 20.44 %
# tokens processed 1960465408
# iteration step 7730, loss 0.6397, time 2079.45 ms, mfu 20.45 %
# tokens processed 1963086848
# iteration step 7740, loss 0.7059, time 2049.78 ms, mfu 20.74 %
# tokens processed 1965708288
# iteration step 7750, loss 0.6884, time 2040.37 ms, mfu 20.84 %
# tokens processed 1968329728
# iteration step 7760, loss 0.6800, time 2054.10 ms, mfu 20.70 %
# tokens processed 1970951168
# iteration step 7770, loss 0.6690, time 2079.89 ms, mfu 20.44 %
# tokens processed 1973572608
# iteration step 7780, loss 0.6860, time 2079.58 ms, mfu 20.44 %
# tokens processed 1976194048
# iteration step 7790, loss 0.6129, time 2058.44 ms, mfu 20.65 %
# tokens processed 1978815488
# step: 7800, train_loss: 0.6344154477119446, eval_loss: 0.6312544345855713
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a big , strong lion . He lived in a jungle with his friends . One day , the lion and his friends decided to play a game of hide - and - seek . The lion was very good at hiding , but one of his friends found him too rough . The lion felt guilty and said sorry to his friend . Later that day , the lion ' s friends realized that they didn ' t want to play with a new game of hide - and - seek . They were happy to play without playing a game . The other friend forgave him and they became friends again . They still played hide and - seek , but they still had fun looking for each other . The moral of the story is that it ' s important to try to accept what ' s best to do and accept what others have for ourselves . --
# iteration step 7800, loss 0.5630, time 65666.09 ms, mfu 0.65 %
# tokens processed 1981436928
# iteration step 7810, loss 0.6815, time 2059.92 ms, mfu 20.64 %
# tokens processed 1984058368
# iteration step 7820, loss 0.7649, time 2080.11 ms, mfu 20.44 %
# tokens processed 1986679808
# iteration step 7830, loss 0.6466, time 2054.73 ms, mfu 20.69 %
# tokens processed 1989301248
# iteration step 7840, loss 0.6455, time 2042.67 ms, mfu 20.81 %
# tokens processed 1991922688
# iteration step 7850, loss 0.6846, time 2052.24 ms, mfu 20.72 %
# tokens processed 1994544128
# iteration step 7860, loss 0.6981, time 2061.11 ms, mfu 20.63 %
# tokens processed 1997165568
# iteration step 7870, loss 0.6851, time 2061.99 ms, mfu 20.62 %
# tokens processed 1999787008
# iteration step 7880, loss 0.7160, time 2041.08 ms, mfu 20.83 %
# tokens processed 2002408448
# iteration step 7890, loss 0.6542, time 2018.67 ms, mfu 21.06 %
# tokens processed 2005029888
# step: 7900, train_loss: 0.6232913136482239, eval_loss: 0.6311075091362
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- there was a strange bug . He felt so scared that he couldn ' t find a place to hide . He didn ' t know what to do , so he just kept hopping around looking for a place to hide . Just when he was getting tired of hopping around , he heard a voice behind him . " Stop ?", said the voice . He turned around and saw a small bear . " What are you doing here ?", the bear asked . " I ' m just looking for a place to hide ," said the bug . " Oh , I have one bed in my den ," said the bear . " Would you like to please have this sleep ?" The bug agreed , and so the bear settled in and the bug curled up and soon enough he was fast asleep . The mouse was so comfortable and safe , that he quickly drif ted off to sleep . The bear listened , and then he went off to his secret place . As he na pped he felt a sense of peace and joy as he drif ted off to sleep . --
# iteration step 7900, loss 0.6508, time 65944.08 ms, mfu 0.64 %
# tokens processed 2007651328
# iteration step 7910, loss 0.6469, time 2024.88 ms, mfu 21.00 %
# tokens processed 2010272768
# iteration step 7920, loss 0.6455, time 2050.17 ms, mfu 20.74 %
# tokens processed 2012894208
# iteration step 7930, loss 0.7064, time 2038.45 ms, mfu 20.86 %
# tokens processed 2015515648
# iteration step 7940, loss 0.6119, time 2023.41 ms, mfu 21.01 %
# tokens processed 2018137088
# iteration step 7950, loss 0.6816, time 2065.59 ms, mfu 20.58 %
# tokens processed 2020758528
# iteration step 7960, loss 0.7088, time 2058.33 ms, mfu 20.66 %
# tokens processed 2023379968
# iteration step 7970, loss 0.7146, time 2038.94 ms, mfu 20.85 %
# tokens processed 2026001408
# iteration step 7980, loss 0.6684, time 2039.04 ms, mfu 20.85 %
# tokens processed 2028622848
# iteration step 7990, loss 0.6157, time 2050.22 ms, mfu 20.74 %
# tokens processed 2031244288
# step: 8000, train_loss: 0.6363388895988464, eval_loss: 0.6428341865539551
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl named Lily who had a pair of red shoes . She loved those shoes and wore them every day . One day , Lily playing outside when she accidentally broke her favorite red shoes . Lily ' s owner came outside and saw her looking sad . She said , " Lily , I have a surprise for you ." Lily ran to her grandma and showed her the broken socks . But her grandma said , " Oh no , these socks are good people ! Don ' t worry , we can fix them together ." Lily was happy to hear that . So , they worked together to fix her bad socks . When they finished , Lily was able to wear her new sock again . She was happy to be able to play outside and rest . She realized that it ' s important to help others and to take care of yourself . --
# iteration step 8000, loss 0.6184, time 65730.29 ms, mfu 0.65 %
# tokens processed 2033865728
# iteration step 8010, loss 0.7094, time 1999.40 ms, mfu 21.26 %
# tokens processed 2036487168
# iteration step 8020, loss 0.6061, time 1997.45 ms, mfu 21.28 %
# tokens processed 2039108608
# iteration step 8030, loss 0.7221, time 1998.03 ms, mfu 21.28 %
# tokens processed 2041730048
# iteration step 8040, loss 0.6483, time 2013.65 ms, mfu 21.11 %
# tokens processed 2044351488
# iteration step 8050, loss 0.7126, time 2061.76 ms, mfu 20.62 %
# tokens processed 2046972928
# iteration step 8060, loss 0.7075, time 2059.27 ms, mfu 20.65 %
# tokens processed 2049594368
# iteration step 8070, loss 0.7540, time 2037.27 ms, mfu 20.87 %
# tokens processed 2052215808
# iteration step 8080, loss 0.6513, time 2044.83 ms, mfu 20.79 %
# tokens processed 2054837248
# iteration step 8090, loss 0.6552, time 2050.83 ms, mfu 20.73 %
# tokens processed 2057458688
# step: 8100, train_loss: 0.6256654262542725, eval_loss: 0.629387617111206
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a boy named Timmy who loved to play with his toy ship . One day , he wanted to build a ship out of blocks , but it was too hard . Timmy ' s mom saw him and asked , " What ' s wrong , Timmy ?" " I want to build a ship , but I can ' t fix it ," Timmy replied . " Don ' t worry , we can support your ship ," his mom said . She picked up a long stick and helped Timmy build the ship . Timmy was happy to have his ship to play with . As they were working , Timmy noticed a big octopus scoop ing up sea weed . " Mommy , the octopus is so ugly !" Timmy said . " Don ' t worry , Timmy . The octopus just wants some food ," his mom said . Timmy felt better and they continued to play with their ship s . Later that day , Timmy ' s dad came home from work and saw the octopus playing with the treasure . " Look , Timmy ! A octopus , we made a great team !" his dad said . Timmy was happy to hear that even the ugly octopus seems happy too . --
# iteration step 8100, loss 0.6993, time 66073.75 ms, mfu 0.64 %
# tokens processed 2060080128
# iteration step 8110, loss 0.6430, time 2019.57 ms, mfu 21.05 %
# tokens processed 2062701568
# iteration step 8120, loss 0.7089, time 2019.59 ms, mfu 21.05 %
# tokens processed 2065323008
# iteration step 8130, loss 0.6726, time 2050.99 ms, mfu 20.73 %
# tokens processed 2067944448
# iteration step 8140, loss 0.5987, time 2043.11 ms, mfu 20.81 %
# tokens processed 2070565888
# iteration step 8150, loss 0.7271, time 2035.59 ms, mfu 20.89 %
# tokens processed 2073187328
# iteration step 8160, loss 0.6251, time 2039.95 ms, mfu 20.84 %
# tokens processed 2075808768
# iteration step 8170, loss 0.7393, time 2061.76 ms, mfu 20.62 %
# tokens processed 2078430208
# iteration step 8180, loss 0.6471, time 2057.40 ms, mfu 20.66 %
# tokens processed 2081051648
# iteration step 8190, loss 0.6801, time 2055.27 ms, mfu 20.69 %
# tokens processed 2083673088
# step: 8200, train_loss: 0.6302842497825623, eval_loss: 0.6390941143035889
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little bear named Ted . Ted loved to race with his friends . S at ur day , he invited all his animal friends to his house . When they arrived , they all had so much fun racing ! Ted was very popular with all of his animal friends . They ran , jumped , and ran all around the forest . Ted was happy that he invited his animal friends and friends to his house for a race . It was a great feeling for everyone . The end . --
# iteration step 8200, loss 0.7078, time 65276.33 ms, mfu 0.65 %
# tokens processed 2086294528
# iteration step 8210, loss 0.6505, time 2043.37 ms, mfu 20.81 %
# tokens processed 2088915968
# iteration step 8220, loss 0.6765, time 2070.89 ms, mfu 20.53 %
# tokens processed 2091537408
# iteration step 8230, loss 0.6144, time 2048.56 ms, mfu 20.75 %
# tokens processed 2094158848
# iteration step 8240, loss 0.7197, time 2031.55 ms, mfu 20.93 %
# tokens processed 2096780288
# iteration step 8250, loss 0.6376, time 2037.09 ms, mfu 20.87 %
# tokens processed 2099401728
# iteration step 8260, loss 0.6269, time 2046.57 ms, mfu 20.77 %
# tokens processed 2102023168
# iteration step 8270, loss 0.6699, time 2035.20 ms, mfu 20.89 %
# tokens processed 2104644608
# iteration step 8280, loss 0.6802, time 2039.84 ms, mfu 20.84 %
# tokens processed 2107266048
# iteration step 8290, loss 0.6641, time 2055.44 ms, mfu 20.68 %
# tokens processed 2109887488
# step: 8300, train_loss: 0.6296038031578064, eval_loss: 0.6328838467597961
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little boy named Timmy . Timmy lived in a dark , scary forest with his mommy and daddy . Timmy liked to play with his toys and explore the forest near his home . One day , Timmy ' s mommy asked him if he wanted some yummy juice of cocoa . Timmy said yes and sat down at a table . As he was drinking his cocoa , he noticed a little bird in the tree . The bird had a bright feather on its head and said hello to Timmy . The bird flew across the branches of the tree and landed on Timmy ' s head . Timmy thought the bird looked very pretty . After that , Timmy and his mommy went to the park . They saw other children playing and having fun . Timmy wanted to join them , but he was scared they would be afraid of him . After a while , Timmy ' s mommy told him that it ' s not nice to scare animals , especially the mar vel ous creatures in the forest . From that day on , Timmy learned to be kind and quiet . He didn ' t scare animals or even get into trouble . He made friends with the other children and found other fun things to do . --
# iteration step 8300, loss 0.6656, time 65932.16 ms, mfu 0.64 %
# tokens processed 2112508928
# iteration step 8310, loss 0.7008, time 2018.66 ms, mfu 21.06 %
# tokens processed 2115130368
# iteration step 8320, loss 0.6604, time 2033.14 ms, mfu 20.91 %
# tokens processed 2117751808
# iteration step 8330, loss 0.6792, time 2037.09 ms, mfu 20.87 %
# tokens processed 2120373248
# iteration step 8340, loss 0.6278, time 2038.82 ms, mfu 20.85 %
# tokens processed 2122994688
# iteration step 8350, loss 0.6650, time 2039.64 ms, mfu 20.84 %
# tokens processed 2125616128
# iteration step 8360, loss 0.6857, time 2059.87 ms, mfu 20.64 %
# tokens processed 2128237568
# iteration step 8370, loss 0.6478, time 2058.11 ms, mfu 20.66 %
# tokens processed 2130859008
# iteration step 8380, loss 0.7170, time 2054.02 ms, mfu 20.70 %
# tokens processed 2133480448
# iteration step 8390, loss 0.6816, time 2036.86 ms, mfu 20.87 %
# tokens processed 2136101888
# step: 8400, train_loss: 0.6328654885292053, eval_loss: 0.6286185383796692
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , a green frog named Fred . Fred lived in a nice pond . He had many friends : a frog named Fred the frog named Fred . Fred loved to play with his friends , turt les . They would swim around and have fun all day . One day , Fred and his friends went to the pond to play . They were having so much fun that they forgot to fill any water . Fred ' s friends went to get water , but they forgot and were all wet . Fred was sad because he could not play with his friends anymore . But then , Fred had an idea . He remembered that it was not good to forget too many toys to play with . So , he ran back to the pond and took out some toys from his friends . Now , Fred had a fun day with his friends , and they all played together again . They learned that it was better to leave things to do as long as they got dried . --
# iteration step 8400, loss 0.6628, time 65918.56 ms, mfu 0.64 %
# tokens processed 2138723328
# iteration step 8410, loss 0.6535, time 2036.83 ms, mfu 20.87 %
# tokens processed 2141344768
# iteration step 8420, loss 0.6540, time 2040.89 ms, mfu 20.83 %
# tokens processed 2143966208
# iteration step 8430, loss 0.7009, time 2042.93 ms, mfu 20.81 %
# tokens processed 2146587648
# iteration step 8440, loss 0.6944, time 2036.33 ms, mfu 20.88 %
# tokens processed 2149209088
# iteration step 8450, loss 0.6386, time 2030.15 ms, mfu 20.94 %
# tokens processed 2151830528
# iteration step 8460, loss 0.6597, time 2038.80 ms, mfu 20.85 %
# tokens processed 2154451968
# iteration step 8470, loss 0.6966, time 2050.09 ms, mfu 20.74 %
# tokens processed 2157073408
# iteration step 8480, loss 0.6538, time 2048.00 ms, mfu 20.76 %
# tokens processed 2159694848
# iteration step 8490, loss 0.6701, time 2061.57 ms, mfu 20.62 %
# tokens processed 2162316288
# step: 8500, train_loss: 0.6212302446365356, eval_loss: 0.6275837421417236
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- he swam over some nice rocks . It was lovely ! The bear swam around and played with his friends . They pretended to be a dolphin pool of water and a shark game . They had so much fun ! When the sun started to set , the bear went back to his home . And from that day on , he was always happy and didn ' t worry about the sun setting everyday . It was a lovely sight ! --
# iteration step 8500, loss 0.6705, time 65086.67 ms, mfu 0.65 %
# tokens processed 2164937728
# iteration step 8510, loss 0.6815, time 2016.91 ms, mfu 21.08 %
# tokens processed 2167559168
# iteration step 8520, loss 0.6660, time 2056.47 ms, mfu 20.67 %
# tokens processed 2170180608
# iteration step 8530, loss 0.6762, time 2043.29 ms, mfu 20.81 %
# tokens processed 2172802048
# iteration step 8540, loss 0.6015, time 2041.02 ms, mfu 20.83 %
# tokens processed 2175423488
# iteration step 8550, loss 0.6503, time 2039.03 ms, mfu 20.85 %
# tokens processed 2178044928
# iteration step 8560, loss 0.6635, time 2059.13 ms, mfu 20.65 %
# tokens processed 2180666368
# iteration step 8570, loss 0.6746, time 2059.08 ms, mfu 20.65 %
# tokens processed 2183287808
# iteration step 8580, loss 0.6215, time 2039.78 ms, mfu 20.84 %
# tokens processed 2185909248
# iteration step 8590, loss 0.7123, time 2055.01 ms, mfu 20.69 %
# tokens processed 2188530688
# step: 8600, train_loss: 0.6259366273880005, eval_loss: 0.6373697519302368
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- there was a little girl called Lisa . She was only three years old and loved playing outside with her friends . Every day , Lisa would go outside to play with her friends , but as Lisa did , she noticed something very strange . Whenever she went outside , there was a strange noise from all the cheer . She looked around and saw a girl in a corner of the park . This was an old , spoiled girl and she had lots of colourful spark s inside . Lisa approached the girl and p on der ed at her from a distance . She asked the girl if she wanted to play together . The girl happily accepted and began to play with Rose the whole time . They had so much fun that it became their special b ond . From that day on , Lisa and the poor girl were best friends . Every single day they played together and Lisa taught the girl how to make spark sh own everyone looking so fine . Lisa was so happy to have been able to make a new friend . --
# iteration step 8600, loss 0.7036, time 65795.70 ms, mfu 0.65 %
# tokens processed 2191152128
# iteration step 8610, loss 0.6172, time 2020.42 ms, mfu 21.04 %
# tokens processed 2193773568
# iteration step 8620, loss 0.6064, time 2039.09 ms, mfu 20.85 %
# tokens processed 2196395008
# iteration step 8630, loss 0.6646, time 2040.28 ms, mfu 20.84 %
# tokens processed 2199016448
# iteration step 8640, loss 0.7109, time 2007.63 ms, mfu 21.18 %
# tokens processed 2201637888
# iteration step 8650, loss 0.6988, time 2021.37 ms, mfu 21.03 %
# tokens processed 2204259328
# iteration step 8660, loss 0.6573, time 2016.42 ms, mfu 21.08 %
# tokens processed 2206880768
# iteration step 8670, loss 0.6559, time 2040.17 ms, mfu 20.84 %
# tokens processed 2209502208
# iteration step 8680, loss 0.6900, time 2039.19 ms, mfu 20.85 %
# tokens processed 2212123648
# iteration step 8690, loss 0.6795, time 2043.29 ms, mfu 20.81 %
# tokens processed 2214745088
# step: 8700, train_loss: 0.6275696754455566, eval_loss: 0.6249588131904602
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
# ...
# tokens processed 3858387968
# iteration step 14970, loss 0.6093, time 2084.03 ms, mfu 20.40 %
# tokens processed 3861009408
# iteration step 14980, loss 0.6333, time 2096.73 ms, mfu 20.28 %
# tokens processed 3863630848
# iteration step 14990, loss 0.6324, time 2095.15 ms, mfu 20.29 %
# tokens processed 3866252288
# step: 15000, train_loss: 0.6089780926704407, eval_loss: 0.6002691388130188
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl who wanted to make a special jam . She got the ingredients and started to mix them together . She used the weird things like honey and eggs to make the jam . The little girl was very excited when the jam was ready . She sat down and added the jam to the bowl . She was so proud of her special jam - it was very fancy and shiny . The little girl was so proud of her jam . She decided to have a special party every day . The little girl showed her delicious jam to all her friends , and they were so happy . The little girl was happy and felt really content . The End . --
# iteration step 15000, loss 0.6491, time 66200.52 ms, mfu 0.64 %
# tokens processed 3868873728
# iteration step 15010, loss 0.5615, time 2058.16 ms, mfu 20.66 %
# tokens processed 3871495168
# iteration step 15020, loss 0.7127, time 2079.81 ms, mfu 20.44 %
# tokens processed 3874116608
# iteration step 15030, loss 0.6106, time 2082.83 ms, mfu 20.41 %
# tokens processed 3876738048
# iteration step 15040, loss 0.5858, time 2074.09 ms, mfu 20.50 %
# tokens processed 3879359488
# iteration step 15050, loss 0.6388, time 2079.88 ms, mfu 20.44 %
# tokens processed 3881980928
# iteration step 15060, loss 0.6410, time 2079.58 ms, mfu 20.44 %
# tokens processed 3884602368
# iteration step 15070, loss 0.6224, time 2079.78 ms, mfu 20.44 %
# tokens processed 3887223808
# iteration step 15080, loss 0.6530, time 2079.13 ms, mfu 20.45 %
# tokens processed 3889845248
# iteration step 15090, loss 0.6049, time 2079.21 ms, mfu 20.45 %
# tokens processed 3892466688
# step: 15100, train_loss: 0.6038951873779297, eval_loss: 0.6015753746032715
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- a boy named Timmy went to visit his grandma . She had a cheap toy that Timmy loved very much . Timmy said , " Grandma , I love your toy . Can we play with it now ?" His grandma said , " Sure , Timmy . Let ' s make some cookies ." They went to the kitchen and baked the cookies together . Timmy tasted the cookies and said , " These cookies are yummy ! Can we have some , please ?" His grandma said , " Of course , Timmy . You can have a small piece of the cookie if you want ." They sat down to eat and Timmy said , " They taste good . Can we have another one , grandma ?" His grandma smiled and said , " Of course , Timmy . Let ' s go check my phone and get it fixed ." They went to Timmy ' s house and got the phone fixed . Timmy was happy to have his toy and he was grateful for his grandma ' s help . --
# iteration step 15100, loss 0.6121, time 66880.20 ms, mfu 0.64 %
# tokens processed 3895088128
# iteration step 15110, loss 0.5839, time 2080.74 ms, mfu 20.43 %
# tokens processed 3897709568
# iteration step 15120, loss 0.6173, time 2078.49 ms, mfu 20.45 %
# tokens processed 3900331008
# iteration step 15130, loss 0.6557, time 2090.30 ms, mfu 20.34 %
# tokens processed 3902952448
# iteration step 15140, loss 0.6313, time 2085.20 ms, mfu 20.39 %
# tokens processed 3905573888
# iteration step 15150, loss 0.6158, time 2078.78 ms, mfu 20.45 %
# tokens processed 3908195328
# iteration step 15160, loss 0.5957, time 2078.96 ms, mfu 20.45 %
# tokens processed 3910816768
# iteration step 15170, loss 0.6341, time 2079.14 ms, mfu 20.45 %
# tokens processed 3913438208
# iteration step 15180, loss 0.6124, time 2088.94 ms, mfu 20.35 %
# tokens processed 3916059648
# iteration step 15190, loss 0.6723, time 2077.68 ms, mfu 20.46 %
# tokens processed 3918681088
# step: 15200, train_loss: 0.594866931438446, eval_loss: 0.5921968221664429
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there were two friends who liked to play together . One was a very friendly dog and the other was a smart cat . They went on fun adventures together and they would always have lots of fun ! One day , they decided to go on a special trip to the beach . The sun was shining and the water was sparkling . On their trip , they splashed in the sand and the rocks , made sand castles and chased each other around . Soon they were both so tired that they had to take a rest . Just then , they heard a loud noise coming from across the beach . They both looked up and saw a boy standing on a hill . The boy spoke to the boy in a friendly voice and the two of them hello . The to dd ler was so excited and he asked the to dd ler what he had done . The to dd ler replied , â € œYou made me so happy ! I appeared on this trip to the beach today ! â € The to dd ler and the to dd ler laughed and hugged the boy goodbye . They all agreed that by staying together , they would always have a very fun adventure ! --
# iteration step 15200, loss 0.6614, time 66898.90 ms, mfu 0.64 %
# tokens processed 3921302528
# iteration step 15210, loss 0.6558, time 2078.74 ms, mfu 20.45 %
# tokens processed 3923923968
# iteration step 15220, loss 0.6123, time 2079.52 ms, mfu 20.44 %
# tokens processed 3926545408
# iteration step 15230, loss 0.6786, time 2077.81 ms, mfu 20.46 %
# tokens processed 3929166848
# iteration step 15240, loss 0.6437, time 2078.69 ms, mfu 20.45 %
# tokens processed 3931788288
# iteration step 15250, loss 0.6471, time 2079.50 ms, mfu 20.45 %
# tokens processed 3934409728
# iteration step 15260, loss 0.6221, time 2080.44 ms, mfu 20.44 %
# tokens processed 3937031168
# iteration step 15270, loss 0.6058, time 2079.61 ms, mfu 20.44 %
# tokens processed 3939652608
# iteration step 15280, loss 0.6372, time 2084.43 ms, mfu 20.40 %
# tokens processed 3942274048
# iteration step 15290, loss 0.6658, time 2079.10 ms, mfu 20.45 %
# tokens processed 3944895488
# step: 15300, train_loss: 0.5978785753250122, eval_loss: 0.5947168469429016
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , a little mouse named Timmy was walking in the forest . He was feeling very hungry and decided to look for food . He found a nice piece of cheese and took a bite . Suddenly , he heard a loud noise and started to tremble . Timmy was very scared and didn ' t know what to do . Just then , he saw a big , fierce lion coming towards him . Timmy was so scared that he tripped and fell . The lion caught him in and closed his eyes . Timmy never got to eat his cheese and no one was happy again . --
# iteration step 15300, loss 0.6013, time 66244.78 ms, mfu 0.64 %
# tokens processed 3947516928
# iteration step 15310, loss 0.5917, time 2080.36 ms, mfu 20.44 %
# tokens processed 3950138368
# iteration step 15320, loss 0.6916, time 2079.74 ms, mfu 20.44 %
# tokens processed 3952759808
# iteration step 15330, loss 0.6784, time 2080.03 ms, mfu 20.44 %
# tokens processed 3955381248
# iteration step 15340, loss 0.6182, time 2079.40 ms, mfu 20.45 %
# tokens processed 3958002688
# iteration step 15350, loss 0.6179, time 2079.28 ms, mfu 20.45 %
# tokens processed 3960624128
# iteration step 15360, loss 0.6294, time 2080.00 ms, mfu 20.44 %
# tokens processed 3963245568
# iteration step 15370, loss 0.6517, time 2079.61 ms, mfu 20.44 %
# tokens processed 3965867008
# iteration step 15380, loss 0.6014, time 2079.23 ms, mfu 20.45 %
# tokens processed 3968488448
# iteration step 15390, loss 0.6168, time 2079.16 ms, mfu 20.45 %
# tokens processed 3971109888
# step: 15400, train_loss: 0.6032893657684326, eval_loss: 0.6030768752098083
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl named Lily . She loved to play outside with her friends . One day , they decided to play a game of hide - and - seek . Lily found a leather ball and brought it to her friends . " Let ' s hide behind this spot ," said Lily ' s friend , Timmy . " It ' s very quiet there . You can hear the birds chirping and the clouds doing flowers bloom ." Then , Lily slipped and fell down . Her friends rushed over and asked her to get up . " Are you okay , Lily ?" asked Timmy . " I ' m fine . I just fell down when I tripped over an apple too ." Lily replied . " That ' s okay . Let ' s try again ." And so , they continued playing games , but they never slipped again . --
# iteration step 15400, loss 0.6056, time 66909.73 ms, mfu 0.64 %
# tokens processed 3973731328
# iteration step 15410, loss 0.6743, time 2081.10 ms, mfu 20.43 %
# tokens processed 3976352768
# iteration step 15420, loss 0.6574, time 2075.89 ms, mfu 20.48 %
# tokens processed 3978974208
# iteration step 15430, loss 0.7235, time 2089.49 ms, mfu 20.35 %
# tokens processed 3981595648
# iteration step 15440, loss 0.6410, time 2090.87 ms, mfu 20.33 %
# tokens processed 3984217088
# iteration step 15450, loss 0.6146, time 2094.84 ms, mfu 20.30 %
# tokens processed 3986838528
# iteration step 15460, loss 0.5935, time 2080.06 ms, mfu 20.44 %
# tokens processed 3989459968
# iteration step 15470, loss 0.6881, time 2083.17 ms, mfu 20.41 %
# tokens processed 3992081408
# iteration step 15480, loss 0.6846, time 2083.93 ms, mfu 20.40 %
# tokens processed 3994702848
# iteration step 15490, loss 0.6098, time 2076.03 ms, mfu 20.48 %
# tokens processed 3997324288
# step: 15500, train_loss: 0.6001052260398865, eval_loss: 0.6037689447402954
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was an adorable little lion . He lived in a big forest with his family . One day , a big storm came and the little lion wanted to find a cold place to rest . He saw a big hole in the ground and thought it would be a good place to hide . The little lion made a little nest at the bottom of the hole and waited for the storm to pass . After a while , the storm went away and the sun came out . The little lion came out of his safe hiding spot and went back to the forest to rest . From that day on , the little lion made sure to stay safe and take care of himself before exploring the forest . --
# iteration step 15500, loss 0.6454, time 66758.64 ms, mfu 0.64 %
# tokens processed 3999945728
# iteration step 15510, loss 0.6349, time 2079.11 ms, mfu 20.45 %
# tokens processed 4002567168
# iteration step 15520, loss 0.6151, time 2080.38 ms, mfu 20.44 %
# tokens processed 4005188608
# iteration step 15530, loss 0.5618, time 2080.04 ms, mfu 20.44 %
# tokens processed 4007810048
# iteration step 15540, loss 0.6388, time 2079.49 ms, mfu 20.45 %
# tokens processed 4010431488
# iteration step 15550, loss 0.6693, time 2078.82 ms, mfu 20.45 %
# tokens processed 4013052928
# iteration step 15560, loss 0.6049, time 2080.50 ms, mfu 20.44 %
# tokens processed 4015674368
# iteration step 15570, loss 0.5749, time 2095.36 ms, mfu 20.29 %
# tokens processed 4018295808
# iteration step 15580, loss 0.5733, time 2088.59 ms, mfu 20.36 %
# tokens processed 4020917248
# iteration step 15590, loss 0.6678, time 2094.74 ms, mfu 20.30 %
# tokens processed 4023538688
# step: 15600, train_loss: 0.5960853099822998, eval_loss: 0.6005626320838928
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- , there was a little girl called Hannah . She was only three years old , but she had a yacht . It was bright yellow , and she loved it very much . She could not wait for the next adventure to arrive . So , the next day she was very excited . Maybe in a dream , she raced outside to wave at the yacht . U p , up , up she flew until she finally arrived at the yacht . It was very rough , but the whole journey was very exciting . She explored the yacht and it was the most she had ever seen . As she sailed closer to the edge , Hannah noticed something very strange . There was a secret door at the front of the yacht . She quickly opened it and what she found surprised her !" There was a map , but the map said that lived a secret place . Hannah thought it was the key to her dream . Little did she know , this box was on the yacht . She quickly figured out what it meant , and a secret hidden cave just waiting for her . Hannah followed the map , feeling very excited . Soon she was ready to go exploring the mysterious cave . --
# iteration step 15600, loss 0.6882, time 66989.82 ms, mfu 0.63 %
# tokens processed 4026160128
# iteration step 15610, loss 0.5874, time 2058.54 ms, mfu 20.65 %
# tokens processed 4028781568
# iteration step 15620, loss 0.6163, time 2080.13 ms, mfu 20.44 %
# tokens processed 4031403008
# iteration step 15630, loss 0.6737, time 2092.62 ms, mfu 20.32 %
# tokens processed 4034024448
# iteration step 15640, loss 0.5671, time 2099.50 ms, mfu 20.25 %
# tokens processed 4036645888
# iteration step 15650, loss 0.6689, time 2080.22 ms, mfu 20.44 %
# tokens processed 4039267328
# iteration step 15660, loss 0.6755, time 2078.49 ms, mfu 20.45 %
# tokens processed 4041888768
# iteration step 15670, loss 0.6667, time 2079.49 ms, mfu 20.45 %
# tokens processed 4044510208
# iteration step 15680, loss 0.5901, time 2082.77 ms, mfu 20.41 %
# tokens processed 4047131648
# iteration step 15690, loss 0.6058, time 2098.50 ms, mfu 20.26 %
# tokens processed 4049753088
# step: 15700, train_loss: 0.6073040962219238, eval_loss: 0.6014024615287781
# saving checkpoint to drive/MyDrive/chkpt.pt...
# Generated story:
#  -- there lived two friends - a dolphin and a fish . They lived in a big sea and enjoyed playing together all day . One day , the dolphin said to the fish " Let ' s go say hi to someone in the sea ." The fish replied " Yes !" and they swam closer to the group . When they got there , the dolphin saw a smelly sen sat ion near the other side of the sea . " What a strange sen sat ion ! You look very smelly !" said the monkey . " I ' m Jo lly ," said the dolphin . " The smell is making us feel funny ." The dolphin laughed . " Let ' s find out !" The two friends swam in the smelly swa ppy , but they soon found out it was no one else . They realised their mistake and felt very bad . So the dolphin and the fish decided to say goodbye to each other and swim off . They vowed to never ignore each other again . --
# iteration step 15700, loss 0.6389, time 66779.37 ms, mfu 0.64 %
# tokens processed 4052374528
# iteration step 15710, loss 0.6099, time 2079.83 ms, mfu 20.44 %
# tokens processed 4054995968
# iteration step 15720, loss 0.6386, time 2078.98 ms, mfu 20.45 %
# tokens processed 4057617408
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-f923d9bad3eb> in <cell line: 0>()
# ----> 1 train_GPT(TrainningConfig, device, chkpt_path)
#
# <ipython-input-29-34daa7f98634> in train_GPT(TrainningConfig, device, chkpt_path)
#      75         acc_loss += loss
#      76         X, Y = get_batch('train') # prefetch, while GPU doing backprop
# ---> 77         scaler.scale(loss).backward() # pytorch accumulates gradients automatically
#      78
#      79     if TrainningConfig.grad_clip != 0:
#
# /usr/local/lib/python3.11/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     624                 inputs=inputs,
#     625             )
# --> 626         torch.autograd.backward(
#     627             self, gradient, retain_graph, create_graph, inputs=inputs
#     628         )
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     345     # some Python versions print out the first line of a multi-line function
#     346     # calls in the traceback and some print out the last line
# --> 347     _engine_run_backward(
#     348         tensors,
#     349         grad_tensors_,
#
# /usr/local/lib/python3.11/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     821         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     822     try:
# --> 823         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     824             t_outputs, *args, **kwargs
#     825         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# Let's try a prompt and see what the model outputs

# %%
model.eval()
# Out:
# GPT(
#   (transformer): ModuleDict(
#     (token_embed): Embedding(6000, 512)
#     (pos_embed): Embedding(512, 512)
#     (drop): Dropout(p=0.2, inplace=False)
#     (blocks): ModuleList(
#       (0-7): 8 x Block(
#         (norm1): RMSNorm((512,), eps=None, elementwise_affine=True)
#         (Causal_attention): CausalAttention(
#           (QKV): Linear(in_features=512, out_features=1536, bias=False)
#           (out): Linear(in_features=512, out_features=512, bias=False)
#           (att_dropout): Dropout(p=0.2, inplace=False)
#           (out_dropout): Dropout(p=0.2, inplace=False)
#         )
#         (norm2): RMSNorm((512,), eps=None, elementwise_affine=True)
#         (Feed_forward): SWIGLUFFN(
#           (layer1): Linear(in_features=512, out_features=1365, bias=False)
#           (silu): SiLU()
#           (layer2): Linear(in_features=512, out_features=1365, bias=False)
#           (layer3): Linear(in_features=1365, out_features=512, bias=False)
#           (dropout): Dropout(p=0.2, inplace=False)
#         )
#       )
#     )
#     (norm): RMSNorm((512,), eps=None, elementwise_affine=True)
#   )
#   (projection): Linear(in_features=512, out_features=6000, bias=False)
# )

# %%
print(f"number of tokens processed: {num_tokens}")  # ~4B tokens
# Out:
# 4052374528

# %%
prompt_ids = tokenizer.encode("once upon a time,").ids
prompt_ids = torch.tensor(prompt_ids, dtype=torch.int64, device=device).unsqueeze(0)

# %%
story, _ = model.generate(prompt_ids, max_samples=350)

# %%
print(tokenizer.decode(story.squeeze(0).tolist())) # example story
# Out:
# once upon a time , there was a mysterious dog . He wanted to burn things , but he was scared factory s are be matched . One day , he saw smoke coming from the factory . He had heard of them before , but something was different . He was afraid that something was going to happen away . He barked loudly but nobody answered . Then he heard a little voice . " I ' m just a statue of those things . Don ' t be scared !" It came a little bird singing in the corner of the factory . The dog stopped his barking and the bird flew away . The dog felt relieved . He was no longer scared of the factory . He knew his mom would always find him and his toy was all ready to burning things .

# %%
# !pip install gradio  # gradio for a nice and simple UI

# %%
# load our latest checkpoint

model, resume, iter_num, num_tokens, best_val_loss, checkpoint = load_model(chkpt_path, device)
# Out:
# trainning Resumed from 15700 steps with 0.6005626320838928 as best_val_loss.

# %%
import gradio as gr

def chat_with_model(prompt):
    prompt_ids = tokenizer.encode(prompt).ids
    prompt_ids = torch.tensor(prompt_ids, dtype=torch.int64, device=device).unsqueeze(0)
    generated, _ = model.generate(prompt_ids, eos_id=1 , max_samples=350, temperature=1.0, top_p=0.8)
    generated_story = tokenizer.decode(generated.squeeze(0).tolist(), skip_special_tokens=True)
    return f" Story:\n {generated_story}"

iface = gr.Interface(
    fn=chat_with_model,
    inputs=gr.Textbox(lines=2, placeholder="Type just the beginning of the story (like once upon a time)..."),
    outputs=gr.Textbox(),
    title="TinyGPT",
    description="A custom GPT-style model trained on TinyStories. Only ask it to write fun-child stories!"
)

# %%
iface.launch()
# Out:
# It looks like you are running Gradio on a hosted a Jupyter notebook. For the Gradio app to work, sharing must be enabled. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://16219f8a664eb636e6.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://16219f8a664eb636e6.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Doesn't work currently but hopefully you get the idea!
